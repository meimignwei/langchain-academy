# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/trim-filter-messages.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239435-lesson-4-trim-and-filter-messages)

# %% [markdown]
# # Filtering and trimming messages
#
# ## Review
#
# Now, we have a deeper understanding of a few things:
#
# * How to customize the graph state schema
# * How to define custom state reducers
# * How to use multiple graph state schemas
#
# ## Goals
#
# Now, we can start using these concepts with models in LangGraph!
#
# In the next few sessions, we'll build towards a chatbot that has long-term memory.
#
# Because our chatbot will use messages, let's first talk a bit more about advanced ways to work with messages in graph state.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph langchain_openai

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# We'll use [LangSmith](https://docs.langchain.com/langsmith/home) for [tracing](https://docs.langchain.com/langsmith/observability-concepts).
#
# We'll log to a project, `langchain-academy`.

# %%
os.environ["LANGSMITH_API_KEY"] = os.getenv("LANGSMITH_API_KEY", "")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langchain-academy"

# %% [markdown]
# ## Messages as state
#
# First, let's define some messages.

# %%
from pprint import pprint
from langchain_core.messages import AIMessage, HumanMessage
messages = [AIMessage(f"So you said you were researching ocean mammals?", name="Bot")]
messages.append(HumanMessage(f"Yes, I know about whales. But what others should I learn about?", name="Lance"))

for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?

# %% [markdown]
# Recall we can pass them to a chat model.

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="deepseek-chat", base_url="https://api.deepseek.com")
llm.invoke(messages)
# Out:
# AIMessage(content='Excellent follow-up question! Whales are a fantastic starting point, but the world of marine mammals is incredibly diverse. Here\'s a breakdown of the other major groups you should definitely learn about, from the most famous to the more obscure.\n\nThink of it this way: whales (cetaceans) are just one branch of the tree. The other main branches are pinnipeds, sirenians, and marine fissipeds.\n\n### 1. Pinnipeds: The "Fin-Feet" (Seals, Sea Lions, and Walruses)\n\nThese are probably the most well-known marine mammals after whales. They are characterized by having flippers for both front and back limbs.\n\n- **True Seals (Phocidae):** No external ear flaps. They are more streamlined in the water and move on land by flopping on their bellies (like a caterpillar).\n    - **Learn about:** **Elephant Seals** (the massive, trunk-nosed bulls that fight for dominance) and **Leopard Seals** (the apex predators of the Antarctic, known for hunting penguins and even other seals).\n\n- **Eared Seals (Otariidae):** These have small, visible external ear flaps. Their rear flippers can rotate forward, allowing them to walk or even run on land (like a dog). This group includes **sea lions** and **fur seals**.\n    - **Learn about:** **California Sea Lions** (the "circus seals" you see in zoos, incredibly smart and social) and **Steller Sea Lions** (the largest species, a true giant).\n\n- **Walruses (Odobenidae):** The only living member of this family. They are instantly recognizable by their two long, ivory tusks (which are actually elongated canine teeth).\n    - **Why they are fascinating:** Their tusks are used for hauling out onto ice, fighting, and as a status symbol. They have the most sensitive whiskers (vibrissae) of any mammal, which they use to find clams on the dark ocean floor by touch.\n\n### 2. Sirenians: The "Sea Cows" (Manatees and Dugongs)\n\nThese are the only fully aquatic, herbivorous marine mammals. They are gentle, slow-moving giants that graze on seagrass. They are more closely related to elephants and hyraxes than to whales or seals.\n\n- **Manatees (Trichechidae):** Found in warm, shallow coastal waters and rivers (Florida, Caribbean, Amazon, West Africa). They have a rounded, paddle-like tail.\n    - **Key trait:** They are the "vacuum cleaners of the sea," using their flexible, split upper lip to tear and eat plants. They need to surface to breathe but can hold their breath for up to 20 minutes while resting.\n\n- **Dugongs (Dugongidae):** Found in the Indo-Pacific (around Australia, East Africa, Southeast Asia). They have a fluked tail, similar to a whale\'s, and a more down-turned snout.\n    - **Key trait:** The only strictly marine herbivorous mammal. The now-extinct **Steller\'s Sea Cow** was a massive (up to 10 tons!) relative of the dugong, hunted to extinction in the 18th century—a tragic early lesson in conservation.\n\n### 3. Marine Fissipeds: The "Split-Feet" (Otters, Polar Bear)\n\nThis is a bit of a catch-all term for carnivorous mammals that are not pinnipeds but have adapted to a marine or semi-marine life.\n\n- **Sea Otter (Enhydra lutris):** The smallest marine mammal in North America and arguably the most important.\n    - **Why they are a must-learn:** They are a **keystone species**. They have the densest fur of any animal (up to 1 million hairs per square inch!) which keeps them warm, as they have no blubber. They use tools (rocks) to crack open shellfish. By eating sea urchins, they protect kelp forests from being overgrazed, creating an entire underwater ecosystem.\n\n- **Polar Bear (Ursus maritimus):** The largest land carnivore on Earth, but classified as a **marine mammal** because it spends most of its life on sea ice and depends on the ocean for its food (primarily seals).\n    - **Why they are unique:** They are incredibly adapted to their environment: black skin under transparent fur, powerful swimmers, and a highly sensitive nose that can detect a seal from a mile aw ...

# %% [markdown]
# We can run our chat model in a simple graph with `MessagesState`.

# %%
from IPython.display import Image, display
from langgraph.graph import MessagesState
from langgraph.graph import StateGraph, START, END

# Node
def chat_model_node(state: MessagesState):
    return {"messages": llm.invoke(state["messages"])}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's a great starting point—whales are fascinating! If you're ready to expand your knowledge beyond them, the ocean is home to a diverse group of other marine mammals. Here are the main groups you should learn about, each with some key examples:
#
# ### 1. Dolphins & Porpoises (The Other Cetaceans)
#
# Since you know whales, you've already dipped into the *cetacean* family. But whales are just one branch. The other two main branches are **dolphins** and **porpoises**.
#
# - **Dolphins:** What's the difference from whales? Generally, dolphins are smaller, have more prominent, beak-like snouts, and cone-shaped teeth. They are famously social and acrobatic.
#     - **Key species to learn:** **Bottlenose Dolphin** (the classic one), **Orca (Killer Whale)** (actually a dolphin species, not a whale!), **Spinner Dolphin** (known for spinning leaps), and **River Dolphins** (like the Amazon River Dolphin, which is a unique freshwater species).
# - **Porpoises:** Often confused with dolphins, but they are distinct. They are generally smaller and stockier, have a blunt, rounded head (no beak), and spade-shaped teeth.
#     - **Key species to learn:** **Harbor Porpoise** (common in cooler waters) and the critically endangered **Vaquita** (the world's smallest and most endangered marine mammal, found only in Mexico's Gulf of California).
#
# ### 2. Pinnipeds ("Fin-feet" - Seals, Sea Lions, and Walruses)
#
# This is a major group of carnivorous, fin-footed, semi-aquatic marine mammals. They are all adapted to spend time both in water and on land (or ice).
#
# - **True Seals (Phocidae):** They have no external ear flaps, have short, non-functional front flippers on land (they "belly crawl"), and swim with their hind flippers.
#     - **Key species:** **Harbor Seal**, **Elephant Seal** (massive size and trunk-like nose in males), **Leopard Seal** (a top predator in Antarctica).
# - **Sea Lions & Fur Seals (Otariidae):** They have small, visible external ear flaps, long, powerful front flippers they use to "walk" on land, and swim with their front flippers.
#     - **Key species:** **California Sea Lion** (the classic "trained seal" you see in shows), **Steller Sea Lion** (the largest), **Northern Fur Seal**.
# - **Walrus (Odobenidae):** The only living species in its family. Instantly recognizable by its long tusks, massive size, and bristly whiskers. They live in the Arctic.
#
# ### 3. Sirenians ("Sea Cows" - Manatees & Dugongs)
#
# These are the gentle, slow-moving, herbivorous marine mammals. Think of them as the cows of the sea. They are the only fully aquatic, plant-eating marine mammals.
#
# - **Key difference from other marine mammals:** They are most closely related to elephants! They have thick, wrinkled skin and a flat, paddle-like tail.
# - **Manatees:** Have a rounded, paddle-shaped tail. They live in warm, shallow coastal waters and rivers.
#     - **Key species:** **West Indian Manatee** (Florida and Caribbean), **Amazonian Manatee**, **West African Manatee**.
# - **Dugongs:** Have a fluked tail (like a whale's, but smaller) and a more streamlined head. They are strictly marine and live in the Indo-Pacific.
#     - **Key species:** The **Dugong** is the only living species. They are famously thought to be the origin of mermaid legends.
#
# ### 4. Marine Otters (The Unique Mustelids)
#
# This is a smaller group, but a fascinating one. While most otters are semi-aquatic (living in rivers and coasts), the **Sea Otter** is a true marine mammal.
#
# - **Sea Otter (Enhydra lutris):** The smallest marine mammal in North America. They have the densest fur of any animal (up to 1 million hairs per square inch) because they have no blubber for insulation. They use tools (like rocks) to open shellfish.
# - **Marine Otter (Lontra felina):** A much rarer, smaller species found only on the rocky coasts of South America. It's less specialized for a fully marine life than the sea otter.
#
# ### 5. Polar Bear (The Marine "White Bear")
#
# This is a special case. Polar bears are classified as **marine mammals** because they depend on the ocean for their food and habitat (sea ice). They are the only bear species considered a marine mammal.
#
# - **Key Adaptations:** They are excellent swimmers, have a thick layer of blubber and waterproof fur, and are the largest land carnivores on Earth. Their primary prey is seals.
#
# ---
#
# ### How to Start Learning Effectively:
#
# 1.  **Pick a Group:** Don't try to learn everything at once. Start with **pinnipeds** since they are visually distinct and common in many aquariums. Then move to **sirenians** (they are unique and fascinating).
# 2.  **Focus on Key Distinctions:** The first thing to learn is **how to tell a seal from a sea lion**. That's a classic marine biology identifier.
# 3.  **Explore a Specific Species:** For each group, choose one amazing species to deep-dive into. For example, the **Vaquita** (porpoise) is a tragic and urgent conservation story. The **Elephant Seal** has incredible diving physiology and a brutal mating system.
# 4.  **Use Great Resources:**
#     - **Websites:** NOAA Fisheries (USA), Ocean Conservancy, WWF, MarineBio.org, IUCN Red List.
#     - **Books:** "The Soul of an Octopus" (not a mammal, but great ocean natural history) or "The Breath of a Whale" by Leigh Calvez.
#     - **Documentaries:** "Our Planet" (Netflix), "Blue Planet II" (BBC), "Seaspiracy" (for the conservation angle, but be critical of it).
#     - **Local:** Visit your nearest aquarium or marine science center. Seeing them in person is unforgettable.
#
# So, to answer your question directly: **Start with Pinnipeds (Seals & Sea Lions) and Sirenians (Manatees & Dugongs).** Those two groups will give you a completely new perspective on ocean mammal life, far beyond the whales. Enjoy the journey

# %% [markdown]
# ## Reducer
#
# A practical challenge when working with messages is managing long-running conversations.
#
# Long-running conversations result in high token usage and latency if we are not careful, because we pass a growing list of messages to the model.
#
# We have a few ways to address this.
#
# First, recall the trick we saw using `RemoveMessage` and the `add_messages` reducer.

# %%
from langchain_core.messages import RemoveMessage

# Nodes
def filter_messages(state: MessagesState):
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"messages": delete_messages}

def chat_model_node(state: MessagesState):    
    return {"messages": [llm.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("filter", filter_messages)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "filter")
builder.add_edge("filter", "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
# Message list with a preamble
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Lance", id="2"))
messages.append(AIMessage("So you said you were researching ocean mammals?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I know about whales. But what others should I learn about?", name="Lance", id="4"))

# Invoke
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# Excellent! If you already know about whales, you have a fantastic foundation. Whales are the superstars, but the ocean is full of other incredible, intelligent, and often bizarre mammals.
#
# Here are the other major groups you should definitely learn about, from the most well-known to some real surprises.
#
# ### 1. Dolphins and Porpoises (The Cetaceans, Part 2)
#
# You probably already know that whales, dolphins, and porpoises are all **cetaceans**. The main split is between baleen whales (like the blue whale) and toothed whales. Dolphins and porpoises are the most famous of the toothed whales.
#
# - **The Difference:** While often used interchangeably, they are different.
#     - **Dolphins:** Usually have a distinctive, curved dorsal fin, a long beak (rostrum), and cone-shaped teeth. They are generally more social and acrobatic. Think Bottlenose or Spinner dolphins.
#     - **Porpoises:** Are smaller, stockier, and have a more triangular, spade-shaped dorsal fin. They have a blunt, rounded head (no beak) and spade-shaped teeth. They are much shyer and less likely to bow-ride than dolphins. The Harbor Porpoise is a common example.
#
# - **Why they're worth learning about:**
#     - **Extreme Intelligence:** Dolphins are renowned for their complex social structures, communication (signature whistles), tool use (sponging in some populations), and self-awareness.
#     - **Amazing Hunters:** Orcas (killer whales) are the largest dolphin species and are apex predators with specialized "ecotypes" that hunt everything from fish to seals to other whales.
#     - **Porpoise Conservation:** Many porpoise species, like the **Vaquita** (the world's most endangered marine mammal), are critically endangered by bycatch in fishing nets.
#
# ### 2. Pinnipeds: "Fin-Feet" (Seals, Sea Lions, and Walruses)
#
# This is the group most people think of after whales. They are semi-aquatic; they must come ashore to breed, give birth, and molt.
#
# - **The Three Families:**
#     1.  **True Seals (Phocidae):** No external ear flaps. They have short front flippers and cannot "walk" on land, moving like a caterpillar. They are more streamlined for ocean swimming. Example: Leopard Seal, Elephant Seal.
#     2.  **Eared Seals (Otariidae):** Have small external ear flaps. Their long front flippers are powerful, allowing them to "walk" on all fours on land. Includes Sea Lions and Fur Seals. Example: California Sea Lion, Northern Fur Seal.
#     3.  **Walrus (Odobenidae):** The only living species. Famous for its long tusks, which are used for hauling out on ice, display, and fighting. They are bottom-feeders, sucking clams and other invertebrates from the seafloor.
#
# - **Why they're worth learning about:**
#     - **Deep Divers:** Elephant Seals are champion divers, holding their breath for over an hour and diving to over 5,000 feet.
#     - **Amazing Adaptations:** They have incredible blood volume and myoglobin (oxygen storage protein) to manage their deep dives.
#     - **Fearsome Predators:** The Leopard Seal is the apex predator of the Antarctic, known for hunting penguins and even other seals.
#
# ### 3. Sirenians: The "Sea Cows" (Manatees and Dugongs)
#
# This is a small, unique group of completely herbivorous marine mammals. They are the only plant-eaters in the ocean.
#
# - **The Species:**
#     - **Manatees:** Three species (West Indian, Amazonian, and African). They have a large, paddle-shaped tail and prefer warm, shallow coastal waters and rivers.
#     - **Dugong:** Found in the Indian and western Pacific Oceans. They have a fluked tail (like a whale's) and males have small tusks. *Steller's Sea Cow* was a giant, now-extinct relative.
#
# - **Why they're worth learning about:**
#     - **Gentle Giants:** They are slow-moving, grazing on seagrasses and algae. They are the inspiration for mermaid legends.
#     - **Key Ecosystem Engineers:** By grazing on seagrass, they promote healthy seagrass beds, which are critical habitats for countless other species.
#     - **Conservation Flagship:** Manatees are highly vulnerable to boat strikes and habitat loss, making them a major focus of conservation efforts.
#
# ### 4. The Surprise: Marine Otters
#
# This is a group you might not have thought of!
#
# - **The Species:**
#     - **Sea Otter:** The smallest marine mammal. It lives in the North Pacific (from California to Alaska and Russia). It is the only marine mammal that doesn't have a layer of blubber to stay warm; it relies on the *densest fur of any animal*.
#     - **Marine Otter:** A smaller, less-well-known otter species found along the coasts of South America.
#
# - **Why they're worth learning about:**
#     - **Tool Users:** Sea Otters are famous for using rocks to smash open shellfish like abalone and clams.
#     - **Keystone Species:** They are a *keystone predator* in kelp forests. By eating sea urchins, they prevent the urchins from overgrazing and destroying the kelp forests, which are vital nurseries for fish and other life.
#     - **Unique Physiology:** They have the highest metabolic rate of any mammal to generate their own heat.
#
# ### 5. The Arctic Specialist: The Polar Bear
#
# You might not think of it as a "marine mammal," but scientifically, it is classified as one because it spends most of its life on sea ice and depends on the ocean for its primary food source (seals).
#
# - **Why it's worth learning about:**
#     - **Apex Marine Predator:** They are the largest land carnivore (though they are classed as marine).
#     - **Incredible Swimmers:** They can swim for days at a time to travel between ice floes.
#     - **Most Vulnerable to Climate Change:** Their entire existence depends on sea ice, making them the primary symbol of the impact of global warming.
#
# ---
#
# ### Recommended Learning Path:
#
# 1.  **Start with Dolphins vs. Porpoises:** Watch videos of the acrobatic Spinner Dolphin and then the shy Harbor Porpoise to see the difference.
# 2.  **Meet the Pinnipeds:** Find a live webcam of California Sea Lions at a harbor (they are very noisy) and compare their movements to video of a Grey Seal crawling on a beach.
# 3.  **The "Cool" Facts:** Dive into the Sea Otter's tool use or the Elephant Seal's incredible diving ability.
# 4.  **Conservation:** Read about the critically endangered **Vaquita** (a porpoise) and the **Manatee**. Their stories are powerful and show the threats these animals face.
#
# Have fun exploring! The world of marine mammals is full of surprises.

# %% [markdown]
# ## Filtering messages
#
# If you don't need or want to modify the graph state, you can just filter the messages you pass to the chat model.
#
# For example, just pass in a filtered list: `llm.invoke(messages[-1:])` to the model.

# %%
# Node
def chat_model_node(state: MessagesState):
    return {"messages": [llm.invoke(state["messages"][-1:])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Let's take our existing list of messages, append the above LLM response, and append a follow-up question.

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me more about Narwhals!", name="Lance"))

# %%
for m in messages:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's great that you know about whales! There are many other fascinating ocean mammals you can learn about. Here are a few:
#
# 1. **Dolphins**: Highly intelligent and social animals, dolphins are known for their playful behavior and sophisticated communication skills. There are many species of dolphins, including the well-known bottlenose dolphin.
#
# 2. **Porpoises**: Often confused with dolphins, porpoises are smaller and have different body shapes and teeth. They are generally more reclusive and less acrobatic than dolphins.
#
# 3. **Seals**: Seals are part of the pinniped family, which also includes sea lions and walruses. They have streamlined bodies and flippers, making them excellent swimmers. Common types of seals include harbor seals and elephant seals.
#
# 4. **Sea Lions**: Similar to seals but with some key differences, sea lions have external ear flaps and can rotate their hind flippers to walk on land. They are also very social and often gather in large groups.
#
# 5. **Walruses**: Recognizable by their long tusks and whiskers, walruses are large marine mammals that are found in Arctic regions. They use their tusks to help them climb out of the water and to break through ice.
#
# 6. **Manatees and Dugongs**: These gentle giants are often referred to as sea cows. Manatees are found in the Atlantic Ocean, while dugongs are found in the Indian and Pacific Oceans. They are herbivores and spend most of their time grazing on underwater vegetation.
#
# 7. **Sea Otters**: Known for their playful behavior and use of tools, sea otters are an important part of the marine ecosystem. They have thick fur to keep them warm in cold waters and are often seen floating on their backs.
#
# 8. **Polar Bears**: While not exclusively marine, polar bears spend a significant amount of time in the ocean, particularly in Arctic regions. They are excellent swimmers and rely on sea ice to hunt seals, their primary food source.
#
# 9. **Narwhals**: Often called the "unicorns of the sea," narwhals have a long, spiral tusk that is actually an elongated tooth. They are found in Arctic waters and are known for their deep diving abilities.
#
# 10. **Orcas (Killer Whales)**: Though they are technically a type of dolphin, orcas are often considered separately due to their size and distinctive black-and-white coloring. They are apex predators and have complex social structures.
#
# Each of these ocean mammals has unique behaviors, adaptations, and ecological roles, making them fascinating subjects for study.
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!

# %%
# Invoke, using message filtering
output = graph.invoke({'messages': messages})
for m in output['messages']:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Name: Bot
#
# Hi.
# ================================ Human Message =================================
# Name: Lance
#
# Hi.
# ================================== Ai Message ==================================
# Name: Bot
#
# So you said you were researching ocean mammals?
# ================================ Human Message =================================
# Name: Lance
#
# Yes, I know about whales. But what others should I learn about?
# ================================== Ai Message ==================================
#
# That's great that you know about whales! There are many other fascinating ocean mammals you can learn about. Here are a few:
#
# 1. **Dolphins**: Highly intelligent and social animals, dolphins are known for their playful behavior and sophisticated communication skills. There are many species of dolphins, including the well-known bottlenose dolphin.
#
# 2. **Porpoises**: Often confused with dolphins, porpoises are smaller and have different body shapes and teeth. They are generally more reclusive and less acrobatic than dolphins.
#
# 3. **Seals**: Seals are part of the pinniped family, which also includes sea lions and walruses. They have streamlined bodies and flippers, making them excellent swimmers. Common types of seals include harbor seals and elephant seals.
#
# 4. **Sea Lions**: Similar to seals but with some key differences, sea lions have external ear flaps and can rotate their hind flippers to walk on land. They are also very social and often gather in large groups.
#
# 5. **Walruses**: Recognizable by their long tusks and whiskers, walruses are large marine mammals that are found in Arctic regions. They use their tusks to help them climb out of the water and to break through ice.
#
# 6. **Manatees and Dugongs**: These gentle giants are often referred to as sea cows. Manatees are found in the Atlantic Ocean, while dugongs are found in the Indian and Pacific Oceans. They are herbivores and spend most of their time grazing on underwater vegetation.
#
# 7. **Sea Otters**: Known for their playful behavior and use of tools, sea otters are an important part of the marine ecosystem. They have thick fur to keep them warm in cold waters and are often seen floating on their backs.
#
# 8. **Polar Bears**: While not exclusively marine, polar bears spend a significant amount of time in the ocean, particularly in Arctic regions. They are excellent swimmers and rely on sea ice to hunt seals, their primary food source.
#
# 9. **Narwhals**: Often called the "unicorns of the sea," narwhals have a long, spiral tusk that is actually an elongated tooth. They are found in Arctic waters and are known for their deep diving abilities.
#
# 10. **Orcas (Killer Whales)**: Though they are technically a type of dolphin, orcas are often considered separately due to their size and distinctive black-and-white coloring. They are apex predators and have complex social structures.
#
# Each of these ocean mammals has unique behaviors, adaptations, and ecological roles, making them fascinating subjects for study.
# ================================ Human Message =================================
# Name: Lance
#
# Tell me more about Narwhals!
# ================================== Ai Message ==================================
#
# Of course! Narwhals (Monodon monoceros) are fascinating marine mammals that belong to the family Monodontidae, which also includes the beluga whale. They are best known for the long, spiral tusk that protrudes from the head of the males, which has earned them the nickname "unicorns of the sea."
#
# Here are some key facts about narwhals:
#
# ### Physical Characteristics
# - **Tusk**: The most distinctive feature of the narwhal is the tusk, which is actually an elongated tooth. It can grow up to 10 feet (3 meters) long and is usually found in males, though some females may also develop smaller tusks. The tusk grows in a spiral pattern and is thought to have sensory capabilities, with millions of nerve endings.
# - **Body**: Narwhals have a stocky body with a mottled black and white skin pattern. They lack a dorsal fin, which is thought to be an adaptation to swimming under ice.
# - **Size**: Adult narwhals typically range from 13 to 20 feet (4 to 6 meters) in length, with males generally being larger than females.
# - **Weight**: They can weigh between 1,760 to 3,530 pounds (800 to 1,600 kilograms).
#
# ### Habitat and Distribution
# - Narwhals are native to the Arctic waters of Canada, Greenland, Norway, and Russia. They are especially common in the Baffin Bay and the waters surrounding Greenland.
# - They prefer deep waters and are often found in areas with heavy sea ice.
#
# ### Behavior and Diet
# - **Diving**: Narwhals are deep divers and can reach depths of up to 5,000 feet (1,500 meters) in search of food. They can hold their breath for up to 25 minutes.
# - **Diet**: Their diet primarily consists of fish such as Arctic cod and Greenland halibut, as well as squid and shrimp.
# - **Social Structure**: Narwhals are social animals and are often found in groups called pods, which typically consist of 5 to 10 individuals but can sometimes number in the hundreds.
#
# ### Reproduction and Lifespan
# - Females give birth to a single calf after a gestation period of about 14 to 15 months. Calves are usually born in the spring or early summer.
# - Narwhals have a long lifespan and can live up to 50 years, although some individuals may live even longer.
#
# ### Conservation Status
# - Narwhals are currently classified as "Near Threatened" by the International Union for Conservation of Nature (IUCN). Their main threats include climate change, which affects their sea ice habitat, and human activities such as shipping and oil exploration.
# - Indigenous communities in the Arctic have traditionally hunted narwhals for their meat, blubber, and tusks, which are used for various purposes, including art and tools.
#
# ### Cultural Significance
# - The narwhal's tusk has fascinated humans for centuries and was often sold as a "unicorn horn" in medieval Europe, believed to possess magical properties.
# - Narwhals hold significant cultural and economic value for indigenous Arctic communities.
#
# Overall, narwhals are remarkable creatures with unique adaptations that allow them to thrive in some of the planet's harshest environments.

# %% [markdown]
# The state has all of the mesages.
#
# But, let's look at the LangSmith trace to see that the model invocation only uses the last message:
#
# https://smith.langchain.com/public/75aca3ce-ef19-4b92-94be-0178c7a660d9/r

# %% [markdown]
# ## Trim messages
#
# Another approach is to [trim messages](https://docs.langchain.com/oss/python/langgraph/add-memory#trim-messages), based upon a set number of tokens.
#
# This restricts the message history to a specified number of tokens.
#
# While filtering only returns a post-hoc subset of the messages between agents, trimming restricts the number of tokens that a chat model can use to respond.
#
# See the `trim_messages` below.

# %%
from langchain_core.messages import trim_messages

# Node
def chat_model_node(state: MessagesState):
    messages = trim_messages(
            state["messages"],
            max_tokens=100,
            strategy="last",
            token_counter=ChatOpenAI(model="deepseek-chat", base_url="https://api.deepseek.com"),
            allow_partial=False,
        )
    return {"messages": [llm.invoke(messages)]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("chat_model", chat_model_node)
builder.add_edge(START, "chat_model")
builder.add_edge("chat_model", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
messages.append(output['messages'][-1])
messages.append(HumanMessage(f"Tell me where Orcas live!", name="Lance"))

# %%
# Example of trimming messages
trim_messages(
            messages,
            max_tokens=100,
            strategy="last",
            token_counter=ChatOpenAI(model="deepseek-chat", base_url="https://api.deepseek.com"),
            allow_partial=False
        )
# Out:
# [HumanMessage(content='Tell me where Orcas live!', name='Lance')]

# %%
# Invoke, using message trimming in the chat_model_node 
messages_out_trim = graph.invoke({'messages': messages})

# %% [markdown]
# Let's look at the LangSmith trace to see the model invocation:
#
# https://smith.langchain.com/public/b153f7e9-f1a5-4d60-8074-f0d7ab5b42ef/r
